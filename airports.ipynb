# %%
import EoN
import networkx as nx
from matplotlib import rc
import matplotlib.pylab as plt
import scipy
import random
import pandas as pd
import EoN

# %%
fh=open('C:/Users/hanna/OneDrive/Documentos/FISICA/4º/CAOS/CORONAVIRUS/US_airports/US_airports.net', 'rb')
G=nx.read_weighted_edgelist(fh)
fh.close()

# %%
node=G.node()

# %%
initial_size = 10000
gamma = 1.
tau = 0.3
t, S, I, R = EoN.fast_SIR(G, tau, gamma, initial_infecteds = range(initial_size))

plt.plot(t, I)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\hanna\Anaconda3\lib\site-packages\networkx\classes\graph.py in neighbors(self, n)
#    1265         try:
# -> 1266             return iter(self._adj[n])
#    1267         except KeyError:
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-44-bca3088ff94f> in <module>
#       2 gamma = 1.
#       3 tau = 0.3
# ----> 4 t, S, I, R = EoN.fast_SIR(G, tau, gamma, initial_infecteds = range(initial_size))
#       5
#       6 plt.plot(t, I)
#
# C:\Users\hanna\Anaconda3\lib\site-packages\EoN\simulation.py in fast_SIR(G, tau, gamma, initial_infecteds, initial_recovereds, rho, tmin, tmax, transmission_weight, recovery_weight, return_full_data, sim_kwargs)
# ...

# %%
EoN.SIS_individual_based(G, tau, gamma, rho=1, nodelist=G.node(), tmin=0, tmax=100, tcount=1001, return_full_data=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-f2649c235469> in <module>
# ----> 1 EoN.SIS_individual_based(G, tau, gamma, rho=1, nodelist=G.node(), tmin=0, tmax=100, tcount=1001, return_full_data=True)
#
# C:\Users\hanna\Anaconda3\lib\site-packages\EoN\analytic.py in SIS_individual_based(G, tau, gamma, rho, Y0, nodelist, tmin, tmax, tcount, transmission_weight, recovery_weight, return_full_data)
#     617     times = np.linspace(tmin, tmax, tcount)
#     618     Y = integrate.odeint(_dSIS_individual_based_, Y0, times,
# --> 619                                     args =(G, nodelist, trans_rate_fxn, rec_rate_fxn))
#     620     Is = Y.T
#     621     Ss = np.ones(len(Is))[:,None]-Is
#
# ...

# %%
EoN.transmission_tree(G, tau, gamma)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-96700129862e> in <module>
# ----> 1 EoN.transmission_tree(G, tau, gamma)
#
# AttributeError: module 'EoN' has no attribute 'transmission_tree'

# %%
EoN.Simulation_Investigation.transmission_tree()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-3d9fe8c89ce6> in <module>
# ----> 1 EoN.Simulation_Investigation.transmission_tree(G)
#
# C:\Users\hanna\Anaconda3\lib\site-packages\EoN\simulation_investigation.py in transmission_tree(self)
#     379         '''
#     380
# --> 381         if self._transmissions_ is None:
#     382             raise EoN.EoNError("transmissions were not provided when created")
#     383
#
# AttributeError: 'Graph' object has no attribute '_transmissions_'

# %%
import EoN
import networkx as nx
import matplotlib.pyplot as plt

from collections import defaultdict


N=1000
gamma = 1
tau = 1.5/N
iterations = 10000
binwidth = 10

H = defaultdict(int)
for counter in range(iterations):
    t, S, I, R = EoN.Gillespie_SIR(G, tau, gamma)
    H[binwidth*(R[-1]/binwidth)] = H[binwidth*(R[-1]/binwidth)]+1./iterations


fig = plt.figure(1)
main = plt.axes()

main.bar(*zip(*H.items()), width = binwidth, linewidth=0)
main.axis(xmax=1000, ymax = 0.7)
plt.xlabel('Final Epidemic Size')
plt.ylabel('Frequency')


inset.bar(*zip(*H.items()), width = binwidth, linewidth=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d33d385f197d> in <module>
#      27
#      28
# ---> 29 inset.bar(*zip(*H.items()), width = binwidth, linewidth=0)
#
# NameError: name 'inset' is not defined

# %%
G.edges(data = True)
# Out:
# EdgeDataView([('0', '110', {'weight': 68150.0}), ('0', '48', {'weight': 110902.0}), ('0', '282', {'weight': 72020.0}), ('0', '176', {'weight': 220192.0}), ('0', '71', {'weight': 164951.0}), ('0', '55', {'weight': 22700.0}), ('0', '47', {'weight': 325839.0}), ('0', '136', {'weight': 171783.0}), ('0', '151', {'weight': 34400.0}), ('0', '50', {'weight': 441099.0}), ('0', '67', {'weight': 474438.0}), ('0', '155', {'weight': 115098.0}), ('0', '40', {'weight': 514446.0}), ('0', '19', {'weight': 913102.0}), ('0', '302', {'weight': 55500.0}), ('0', '122', {'weight': 190185.0}), ('0', '61', {'weight': 372300.0}), ('0', '21', {'weight': 886030.0}), ('0', '100', {'weight': 279330.0}), ('0', '118', {'weight': 247564.0}), ('0', '138', {'weight': 175425.0}), ('0', '157', {'weight': 43267.0}), ('0', '89', {'weight': 367113.0}), ('0', '37', {'weight': 336769.0}), ('0', '11', {'weight': 659832.0}), ('0', '46', {'weight': 358062.0}), ('0', '81', {'weight': 129111.0}), ('0', '120', {'weight': 36375.0})
# ...

# %%
G.nodes(data=True)
# Out:
# NodeDataView({'0': {}, '110': {}, '48': {}, '282': {}, '176': {}, '71': {}, '55': {}, '47': {}, '136': {}, '151': {}, '50': {}, '67': {}, '155': {}, '40': {}, '19': {}, '302': {}, '122': {}, '61': {}, '21': {}, '100': {}, '118': {}, '138': {}, '157': {}, '89': {}, '37': {}, '11': {}, '46': {}, '81': {}, '120': {}, '128': {}, '206': {}, '17': {}, '172': {}, '45': {}, '78': {}, '25': {}, '5': {}, '2': {}, '235': {}, '85': {}, '7': {}, '181': {}, '63': {}, '149': {}, '16': {}, '143': {}, '183': {}, '30': {}, '225': {}, '126': {}, '127': {}, '202': {}, '133': {}, '84': {}, '76': {}, '87': {}, '223': {}, '38': {}, '95': {}, '106': {}, '239': {}, '27': {}, '10': {}, '91': {}, '154': {}, '44': {}, '83': {}, '174': {}, '92': {}, '54': {}, '28': {}, '8': {}, '3': {}, '102': {}, '15': {}, '77': {}, '398': {}, '228': {}, '32': {}, '260': {}, '18': {}, '93': {}, '23': {}, '275': {}, '36': {}, '161': {}, '70': {}, '29': {}, '51': {}, '173': {}, '115': {}, '189': {}, '130': {}, '6': {}, '39': {}, 
# ...

# %%
for n, d in G.degree():
    print('%s %d' % (n, d))
color = '#56c2c4'
options = {
    'node_color': color,
    'node_size': 10,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}

nx.draw_kamada_kawai(G, **options)
plt.show()
# Out:
# 0 145
# 110 15
# 48 40
# 282 1
# 176 4
# 71 35
# 55 34
# 47 30
# 136 6
# 151 5
# 50 33
# 67 26
# 155 8
# 40 53
# 19 68
# 302 1
# 122 7
# 61 28
# 21 70
# 100 15
# 118 8
# 138 5
# 157 8
# 89 15
# 37 66
# 11 94
# 46 34
# 81 16
# 120 4
# 128 12
# 206 2
# 17 114
# 172 6
# 45 14
# 78 22
# 25 64
# 5 122
# 2 132
# 235 1
# 85 19
# 7 114
# 181 13
# 63 18
# 149 7
# 16 85
# 143 7
# 183 2
# 30 46
# 225 2
# 126 9
# 127 9
# 202 2
# 133 5
# 84 16
# 76 18
# 87 18
# 223 4
# 38 30
# 95 21
# 106 11
# 239 3
# 27 75
# 10 109
# 91 12
# 154 2
# 44 40
# 83 15
# 174 7
# 92 11
# 54 30
# 28 44
# 8 74
# 3 76
# 102 14
# 15 67
# 77 18
# 398 3
# 228 4
# 32 67
# 260 2
# 18 72
# 93 16
# 23 61
# 275 4
# 36 84
# 161 4
# 70 20
# 29 42
# 51 53
# 173 5
# 115 10
# 189 7
# 130 5
# 6 130
# 39 40
# 103 13
# 34 35
# 68 22
# 65 21
# 52 21
# 1 136
# 64 24
# 230 6
# 56 24
# 33 46
# 179 6
# 139 7
# 14 89
# 4 91
# 152 8
# 20 110
# 96 11
# 109 15
# 53 27
# 94 15
# 41 42
# 73 18
# 131 10
# 75 22
# 60 30
# 26 42
# 49 29
# 86 12
# ...

# %%
for n, d in G.degree():
    print('%s %d' % (n, d))
color = '#56c2c4'
options = {
    'node_color': color,
    'node_size': 10,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}

nx.draw_circular(G, **options)
plt.show()
# Out:
# 0 145
# 110 15
# 48 40
# 282 1
# 176 4
# 71 35
# 55 34
# 47 30
# 136 6
# 151 5
# 50 33
# 67 26
# 155 8
# 40 53
# 19 68
# 302 1
# 122 7
# 61 28
# 21 70
# 100 15
# 118 8
# 138 5
# 157 8
# 89 15
# 37 66
# 11 94
# 46 34
# 81 16
# 120 4
# 128 12
# 206 2
# 17 114
# 172 6
# 45 14
# 78 22
# 25 64
# 5 122
# 2 132
# 235 1
# 85 19
# 7 114
# 181 13
# 63 18
# 149 7
# 16 85
# 143 7
# 183 2
# 30 46
# 225 2
# 126 9
# 127 9
# 202 2
# 133 5
# 84 16
# 76 18
# 87 18
# 223 4
# 38 30
# 95 21
# 106 11
# 239 3
# 27 75
# 10 109
# 91 12
# 154 2
# 44 40
# 83 15
# 174 7
# 92 11
# 54 30
# 28 44
# 8 74
# 3 76
# 102 14
# 15 67
# 77 18
# 398 3
# 228 4
# 32 67
# 260 2
# 18 72
# 93 16
# 23 61
# 275 4
# 36 84
# 161 4
# 70 20
# 29 42
# 51 53
# 173 5
# 115 10
# 189 7
# 130 5
# 6 130
# 39 40
# 103 13
# 34 35
# 68 22
# 65 21
# 52 21
# 1 136
# 64 24
# 230 6
# 56 24
# 33 46
# 179 6
# 139 7
# 14 89
# 4 91
# 152 8
# 20 110
# 96 11
# 109 15
# 53 27
# 94 15
# 41 42
# 73 18
# 131 10
# 75 22
# 60 30
# 26 42
# 49 29
# 86 12
# ...

# %%
for n, d in G.degree():
    print('%s %d' % (n, d))
color = '#56c2c4'
options = {
    'node_color': color,
    'node_size': 10,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}

nx.draw_networkx(G, **options)
plt.show()
# Out:
# 0 145
# 110 15
# 48 40
# 282 1
# 176 4
# 71 35
# 55 34
# 47 30
# 136 6
# 151 5
# 50 33
# 67 26
# 155 8
# 40 53
# 19 68
# 302 1
# 122 7
# 61 28
# 21 70
# 100 15
# 118 8
# 138 5
# 157 8
# 89 15
# 37 66
# 11 94
# 46 34
# 81 16
# 120 4
# 128 12
# 206 2
# 17 114
# 172 6
# 45 14
# 78 22
# 25 64
# 5 122
# 2 132
# 235 1
# 85 19
# 7 114
# 181 13
# 63 18
# 149 7
# 16 85
# 143 7
# 183 2
# 30 46
# 225 2
# 126 9
# 127 9
# 202 2
# 133 5
# 84 16
# 76 18
# 87 18
# 223 4
# 38 30
# 95 21
# 106 11
# 239 3
# 27 75
# 10 109
# 91 12
# 154 2
# 44 40
# 83 15
# 174 7
# 92 11
# 54 30
# 28 44
# 8 74
# 3 76
# 102 14
# 15 67
# 77 18
# 398 3
# 228 4
# 32 67
# 260 2
# 18 72
# 93 16
# 23 61
# 275 4
# 36 84
# 161 4
# 70 20
# 29 42
# 51 53
# 173 5
# 115 10
# 189 7
# 130 5
# 6 130
# 39 40
# 103 13
# 34 35
# 68 22
# 65 21
# 52 21
# 1 136
# 64 24
# 230 6
# 56 24
# 33 46
# 179 6
# 139 7
# 14 89
# 4 91
# 152 8
# 20 110
# 96 11
# 109 15
# 53 27
# 94 15
# 41 42
# 73 18
# 131 10
# 75 22
# 60 30
# 26 42
# 49 29
# 86 12
# ...

# %%
for n, d in G.degree():
    print('%s %d' % (n, d))
color = '#56c2c4'
options = {
    'node_color': color,
    'node_size': 10,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}

nx.draw_shell(G, **options)
plt.show()
# Out:
# 0 145
# 110 15
# 48 40
# 282 1
# 176 4
# 71 35
# 55 34
# 47 30
# 136 6
# 151 5
# 50 33
# 67 26
# 155 8
# 40 53
# 19 68
# 302 1
# 122 7
# 61 28
# 21 70
# 100 15
# 118 8
# 138 5
# 157 8
# 89 15
# 37 66
# 11 94
# 46 34
# 81 16
# 120 4
# 128 12
# 206 2
# 17 114
# 172 6
# 45 14
# 78 22
# 25 64
# 5 122
# 2 132
# 235 1
# 85 19
# 7 114
# 181 13
# 63 18
# 149 7
# 16 85
# 143 7
# 183 2
# 30 46
# 225 2
# 126 9
# 127 9
# 202 2
# 133 5
# 84 16
# 76 18
# 87 18
# 223 4
# 38 30
# 95 21
# 106 11
# 239 3
# 27 75
# 10 109
# 91 12
# 154 2
# 44 40
# 83 15
# 174 7
# 92 11
# 54 30
# 28 44
# 8 74
# 3 76
# 102 14
# 15 67
# 77 18
# 398 3
# 228 4
# 32 67
# 260 2
# 18 72
# 93 16
# 23 61
# 275 4
# 36 84
# 161 4
# 70 20
# 29 42
# 51 53
# 173 5
# 115 10
# 189 7
# 130 5
# 6 130
# 39 40
# 103 13
# 34 35
# 68 22
# 65 21
# 52 21
# 1 136
# 64 24
# 230 6
# 56 24
# 33 46
# 179 6
# 139 7
# 14 89
# 4 91
# 152 8
# 20 110
# 96 11
# 109 15
# 53 27
# 94 15
# 41 42
# 73 18
# 131 10
# 75 22
# 60 30
# 26 42
# 49 29
# 86 12
# ...

# %%
for n, d in G.degree():
    print('%s %d' % (n, d))
color = '#56c2c4'
options = {
    'node_color': color,
    'node_size': 10,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}

nx.draw_random(G, **options)
plt.show()
# Out:
# 0 145
# 110 15
# 48 40
# 282 1
# 176 4
# 71 35
# 55 34
# 47 30
# 136 6
# 151 5
# 50 33
# 67 26
# 155 8
# 40 53
# 19 68
# 302 1
# 122 7
# 61 28
# 21 70
# 100 15
# 118 8
# 138 5
# 157 8
# 89 15
# 37 66
# 11 94
# 46 34
# 81 16
# 120 4
# 128 12
# 206 2
# 17 114
# 172 6
# 45 14
# 78 22
# 25 64
# 5 122
# 2 132
# 235 1
# 85 19
# 7 114
# 181 13
# 63 18
# 149 7
# 16 85
# 143 7
# 183 2
# 30 46
# 225 2
# 126 9
# 127 9
# 202 2
# 133 5
# 84 16
# 76 18
# 87 18
# 223 4
# 38 30
# 95 21
# 106 11
# 239 3
# 27 75
# 10 109
# 91 12
# 154 2
# 44 40
# 83 15
# 174 7
# 92 11
# 54 30
# 28 44
# 8 74
# 3 76
# 102 14
# 15 67
# 77 18
# 398 3
# 228 4
# 32 67
# 260 2
# 18 72
# 93 16
# 23 61
# 275 4
# 36 84
# 161 4
# 70 20
# 29 42
# 51 53
# 173 5
# 115 10
# 189 7
# 130 5
# 6 130
# 39 40
# 103 13
# 34 35
# 68 22
# 65 21
# 52 21
# 1 136
# 64 24
# 230 6
# 56 24
# 33 46
# 179 6
# 139 7
# 14 89
# 4 91
# 152 8
# 20 110
# 96 11
# 109 15
# 53 27
# 94 15
# 41 42
# 73 18
# 131 10
# 75 22
# 60 30
# 26 42
# 49 29
# 86 12
# ...

# %%
for n, d in G.degree():
    print('%s %d' % (n, d))
color = '#56c2c4'
options = {
    'node_color': color,
    'node_size': 10,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}

nx.draw_spring(G, **options)
plt.show()
# Out:
# 0 145
# 110 15
# 48 40
# 282 1
# 176 4
# 71 35
# 55 34
# 47 30
# 136 6
# 151 5
# 50 33
# 67 26
# 155 8
# 40 53
# 19 68
# 302 1
# 122 7
# 61 28
# 21 70
# 100 15
# 118 8
# 138 5
# 157 8
# 89 15
# 37 66
# 11 94
# 46 34
# 81 16
# 120 4
# 128 12
# 206 2
# 17 114
# 172 6
# 45 14
# 78 22
# 25 64
# 5 122
# 2 132
# 235 1
# 85 19
# 7 114
# 181 13
# 63 18
# 149 7
# 16 85
# 143 7
# 183 2
# 30 46
# 225 2
# 126 9
# 127 9
# 202 2
# 133 5
# 84 16
# 76 18
# 87 18
# 223 4
# 38 30
# 95 21
# 106 11
# 239 3
# 27 75
# 10 109
# 91 12
# 154 2
# 44 40
# 83 15
# 174 7
# 92 11
# 54 30
# 28 44
# 8 74
# 3 76
# 102 14
# 15 67
# 77 18
# 398 3
# 228 4
# 32 67
# 260 2
# 18 72
# 93 16
# 23 61
# 275 4
# 36 84
# 161 4
# 70 20
# 29 42
# 51 53
# 173 5
# 115 10
# 189 7
# 130 5
# 6 130
# 39 40
# 103 13
# 34 35
# 68 22
# 65 21
# 52 21
# 1 136
# 64 24
# 230 6
# 56 24
# 33 46
# 179 6
# 139 7
# 14 89
# 4 91
# 152 8
# 20 110
# 96 11
# 109 15
# 53 27
# 94 15
# 41 42
# 73 18
# 131 10
# 75 22
# 60 30
# 26 42
# 49 29
# 86 12
# ...
