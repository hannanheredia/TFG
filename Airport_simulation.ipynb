# %%
import networkx as nx
import EoN
import matplotlib.pyplot as plt

# %%
fh=open('C:/Users/hanna/OneDrive/Documentos/FISICA/4º/CAOS/CORONAVIRUS/US_airports/US_airports.net', 'rb')
G=nx.read_weighted_edgelist(fh)
fh.close()

# %%
options = {
    'node_size': 10,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}
nx_kwargs = {"with_labels":False, **options} #optional arguments to be passed on to the
#networkx plotting command.
print('doing Gillespie simulation')
sim = EoN.Gillespie_SIR(G, 1, 1, return_full_data=True)
print('done with simulation, now plotting')
sim.display(time =1, **nx_kwargs) #plot at time 1.
plt.show()
# Out:
# doing Gillespie simulation
# done with simulation, now plotting

# %%
T = sim.transmission_tree() #A networkx DiGraph with the transmission tree
Tpos = EoN.hierarchy_pos(T) #pos for a networkx plot
fig = plt.figure(figsize = (8,5))
ax = fig.add_subplot(111)
options = {
    'node_size': 10,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}

nx.draw(T, Tpos, ax=ax, node_size = 10, line_color= 'grey',linewidths= 0, width= 0.1, color_node='red', with_labels=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NetworkXPointlessConcept                  Traceback (most recent call last)
# <ipython-input-9-57504f524e8b> in <module>
#       1 T = sim.transmission_tree() #A networkx DiGraph with the transmission tree
# ----> 2 Tpos = EoN.hierarchy_pos(T) #pos for a networkx plot
#       3 fig = plt.figure(figsize = (8,5))
#       4 ax = fig.add_subplot(111)
#       5 options = {
#
# C:\Users\hanna\Anaconda3\lib\site-packages\EoN\auxiliary.py in hierarchy_pos(G, root, width, vert_gap, vert_loc, leaf_vs_root_factor)
#     240     xcenter: horizontal location of root
#     241     '''
# --> 242     if not nx.is_tree(G):
#     243         raise TypeError('cannot use hierarchy_pos on a graph that is not a tree')
#     244
#
# C:\Users\hanna\Anaconda3\lib\site-packages\networkx\algorithms\tree\recognition.py in is_tree(G)
#     216     """
#     217     if len(G) == 0:
# ...
